# %%
import random
import copy
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error
from reservoirpy import datasets
from reservoirpy.nodes import Reservoir, Ridge
import networkx as nx
import reservoirpy as rpy
rpy.verbosity(0)
# Out:
# 0

# %%
n_timesteps = 2000
X = datasets.mackey_glass(n_timesteps=n_timesteps, sample_len=2000)
Y = np.roll(X, -1)

train_end = int(len(X) * 0.7)
test_start = train_end + 1
X_train, Y_train = X[:train_end], Y[:train_end]
X_test, Y_test = X[test_start:], Y[test_start:]
X_train = X_train.reshape(-1, 1)  # Reshape to (n_samples, 1) if X_train was a flat array


# Example call (Ensure correct values for population_size and genome_length)
population_size = 50
genome_length = 100
n_generations = 20

genome_template = {
    'input_dim': 1,  # Default value
    'output_dim': 1,  # Default value
    'reservoir_size': 100,  # Default value
    'spectral_radius': 0.95,  # Default value
    'leak_rate': 0.2,  # Default value
    'input_scaling': 0.5,  # Default value
    'bias_scaling': 0.5,  # Default value
    # Add other necessary parameters here
}

# %%
def initialize_genome(length):
    """Initializes a genome with a list of random parameters."""
    return {'input_dim': 1, 'output_dim': 1, 
            'reservoir_size': random.randint(50, 200),
            'spectral_radius': random.uniform(0.5, 1.5),
            'leak_rate': random.uniform(0.1, 1.0),
            'input_scaling': random.uniform(0.1, 0.9),
            'bias_scaling': random.uniform(0.1, 0.9)}

# Generate an initial population of genomes
def generate_initial_population(population_size, genome_initializer):
    return [genome_initializer(genome_length) for _ in range(population_size)]


def select_best_genomes(population, fitness_scores, top_k=10):
    sorted_genomes = sorted(zip(population, fitness_scores), key=lambda x: x[1], reverse=True)
    return [genome for genome, _ in sorted_genomes[:top_k]]

def plot_metrics(metrics, title):
    generations = list(range(len(metrics['RMSE'])))
    plt.figure(figsize=(12, 8))
    plt.plot(generations, metrics['RMSE'], label='RMSE')
    plt.plot(generations, metrics['MAE'], label='MAE')
    plt.plot(generations, metrics['MSE'], label='MSE')
    plt.title(title)
    plt.xlabel('Generation')
    plt.ylabel('Score')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
def hox_mutation(genome):
    if len(genome) < 2:
        return genome  # Not enough elements to duplicate
    
    # Convert dictionary keys to a list and pick a random segment to 'duplicate'
    keys = list(genome.keys())
    start = random.randint(0, len(keys) // 2)
    end = random.randint(start + 1, len(keys))
    segment_keys = keys[start:end]
    
    # For simplicity, we could mutate the values of the keys in the segment
    # This is not a direct analog to duplicating a segment in a list but demonstrates
    # modifying a 'segment' of parameters within a dictionary.
    for key in segment_keys:
        # Mutate the parameter slightly
        # This mutation logic will depend on the parameter; this is a placeholder
        if isinstance(genome[key], int):
            genome[key] += random.randint(-10, 10)  # Example mutation for integer parameters
        elif isinstance(genome[key], float):
            genome[key] += random.uniform(-0.1, 0.1)  # Example mutation for float parameters
    
    return genome



def regular_mutation(genome):
    """
    Applies regular mutation to the genome. Mutates a parameter value with some probability.
    """
    # Choose a random parameter to mutate
    param_to_mutate = random.choice(list(genome.keys()))

    # Example mutation process for numeric parameters
    if param_to_mutate in ['reservoir_size', 'input_dim', 'output_dim', 'spectral_radius', 'leak_rate', 'input_scaling', 'bias_scaling']:
        # Apply a mutation by modifying the parameter value slightly
        # This is just an example; the actual mutation logic will depend on the parameter and model needs
        if isinstance(genome[param_to_mutate], int):
            genome[param_to_mutate] += random.randint(-10, 10)  # For integer parameters
        else:
            genome[param_to_mutate] += random.uniform(-0.1, 0.1)  # For floating-point parameters

        # Ensure mutated values remain within logical bounds (example)
        if param_to_mutate == 'spectral_radius':
            genome[param_to_mutate] = max(0.1, min(genome[param_to_mutate], 1.5))
        elif param_to_mutate == 'leak_rate':
            genome[param_to_mutate] = max(0.1, min(genome[param_to_mutate], 1.0))
        # Add similar bounds checks for other parameters as necessary

    # Handle non-numeric parameters or special cases if necessary

    return genome



def mutate_genome(genome):
    """Mutates the genome, with a chance to apply HOX mutations."""
    if random.random() < 0.1:  # Arbitrary probability to apply HOX mutation
        return hox_mutation(genome)
    else:
        # Apply regular mutation
        return regular_mutation(genome)  # This function needs to be defined.
    
def mutate_genome1(genome):
    """Applies mutations to a genome."""
    # This is a placeholder for mutation logic. You might randomly alter parameters.
    mutated_genome = copy.deepcopy(genome)
    if random.random() < 0.1:  # Example mutation rate
        mutated_genome['reservoir_size'] = random.randint(50, 200)  # Example mutation
    return mutated_genome

def reproduce_genomes(selected_genomes, population_size):
    """Generates a new population through reproduction and mutation."""
    new_population = []
    while len(new_population) < population_size:
        parent = random.choice(selected_genomes)
        offspring = mutate_genome(parent)
        new_population.append(offspring)
    return new_population

# %%
def transcribe_genome_to_model_config(genome):
    # Initialize a configuration dictionary with default values
    model_config = {
        'input_dim': 1,  # Default input dimension
        'output_dim': 1,  # Default output dimension
        'reservoir_size': 100,  # Default reservoir size
        'spectral_radius': 0.95,  # Default spectral radius
        'leak_rate': 0.2,  # Default leak rate
        'input_scaling': 0.5,  # Default input scaling
        'bias_scaling': 0.5,  # Default bias scaling
    }

    # Update the model configuration with values from the genome
    # Only update if the parameter exists in the genome
    for param, value in genome.items():
        if param in model_config:
            model_config[param] = value

    # Ensure 'input_dim' matches your actual input data's feature dimension
    # If your data has a different number of features, adjust 'input_dim' accordingly
    # For example, if your data has 2 features, you should set 'input_dim' to 2
    model_config['input_dim'] = 2  # Uncomment and adjust as necessary based on your data

    return model_config




def setup_model(model_config):
    model = Reservoir(units=model_config['reservoir_size'],
                    sr=model_config['spectral_radius'],
                    Win=np.random.uniform(-model_config['input_scaling'], model_config['input_scaling'], 
                    (model_config['reservoir_size'], model_config['input_dim'])),
                    bias=np.random.uniform(-model_config['bias_scaling'], model_config['bias_scaling'], (model_config['reservoir_size'], 1)))
    readout = Ridge(output_dim=model_config['output_dim'])
    esn = model >> readout
    return esn

def evaluate_fitness(genome, X_train, Y_train, X_test, Y_test):
    model_config = transcribe_genome_to_model_config(genome)
    model = setup_model(model_config)
    
    # Train the model and generate predictions
    model.fit(X_train, Y_train)
    predictions = model.run(X_test)
    
    rmse, mae, mse = evaluate_performance(Y_test, predictions)
    return rmse, mae, mse

def evaluate_performance(real, predicted):
    rmse = np.sqrt(mean_squared_error(real, predicted))
    mae = mean_absolute_error(real, predicted)
    mse = mean_squared_error(real, predicted)
    return rmse, mae, mse

# %%
def run_evolution(population_size, genome_length, n_generations, X_train, Y_train, X_test, Y_test):
    population = generate_initial_population(population_size, initialize_genome)
    metrics = {'RMSE': [], 'MAE': [], 'MSE': []}
    
    for generation in range(n_generations):
        fitness_scores = [evaluate_fitness(genome, X_train, Y_train, X_test, Y_test) for genome in population]
        metrics['RMSE'].append(np.mean([fs[0] for fs in fitness_scores]))
        metrics['MAE'].append(np.mean([fs[1] for fs in fitness_scores]))
        metrics['MSE'].append(np.mean([fs[2] for fs in fitness_scores]))
        
        best_genomes = select_best_genomes(population, fitness_scores)
        population = reproduce_genomes(best_genomes, population_size)
        
        print(f"Generation {generation}: Best RMSE: {min(metrics['RMSE'])}, Best MAE: {min(metrics['MAE'])}, Best MSE: {min(metrics['MSE'])}")
    
    plot_metrics(metrics, "Evolution of Performance Metrics")

run_evolution(population_size, genome_length, n_generations, X_train, Y_train, X_test, Y_test)
# Out:
# /Users/chaitravshetty/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/nodes/readouts/ridge.py:17: LinAlgWarning: Ill-conditioned matrix (rcond=2.28475e-22): result may not be accurate.
#   return linalg.solve(XXT + ridge, YXT.T, assume_a="sym")
# /Users/chaitravshetty/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/nodes/readouts/ridge.py:17: LinAlgWarning: Ill-conditioned matrix (rcond=4.79718e-21): result may not be accurate.
#   return linalg.solve(XXT + ridge, YXT.T, assume_a="sym")
# /Users/chaitravshetty/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/nodes/readouts/ridge.py:17: LinAlgWarning: Ill-conditioned matrix (rcond=7.68691e-20): result may not be accurate.
#   return linalg.solve(XXT + ridge, YXT.T, assume_a="sym")
# /Users/chaitravshetty/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/nodes/readouts/ridge.py:17: LinAlgWarning: Ill-conditioned matrix (rcond=6.67089e-17): result may not be accurate.
#   return linalg.solve(XXT + ridge, YXT.T, assume_a="sym")
# /Users/chaitravshetty/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/nodes/readouts/ridge.py:17: LinAlgWarning: Ill-conditioned matrix (rcond=1.8562e-20): result may not be accurate.
#   return linalg.solve(XXT + ridge, YXT.T, assume_a="sym")
# /Users/chaitravshetty/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/nodes/readouts/ridge.py:17: LinAlgWarning: Ill-conditioned matrix (rcond=1.39027e-20): result may not be accurate.
#   return linalg.solve(XXT + ridge, YXT.T, assume_a="sym")
# /Users/chaitravshetty/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/nodes/readouts/ridge.py:17: LinAlgWarning: Ill-conditioned matrix (rcond=1.20143e-20): result may not be accurate.
#   return linalg.solve(XXT + ridge, YXT.T, assume_a="sym")
# /Users/chaitravshetty/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/nodes/readouts/ridge.py:17: LinAlgWarning: Ill-conditioned matrix (rcond=1.05375e-21): result may not be accurate.
#   return linalg.solve(XXT + ridge, YXT.T, assume_a="sym")
# /Users/chaitravshetty/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/nodes/readouts/ridge.py:17: LinAlgWarning: Ill-conditioned matrix (rcond=4.42393e-21): result may not be accurate.
#   return linalg.solve(XXT + ridge, YXT.T, assume_a="sym")
# /Users/chaitravshetty/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/nodes/readouts/ridge.py:17: LinAlgWarning: Ill-conditioned matrix (rcond=1.03309e-20): result may not be accurate.
#   return linalg.solve(XXT + ridge, YXT.T, assume_a="sym")
# /Users/chaitravshetty/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/nodes/readouts/ridge.py:17: LinAlgWarning: Ill-conditioned matrix (rcond=2.38397e-20): result may not be accurate.
#   return linalg.solve(XXT + ridge, YXT.T, assume_a="sym")
# /Users/chaitravshetty/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/nodes/readouts/ridge.py:17: LinAlgWarning: Ill-conditioned matrix (rcond=2.14616e-19): result may not be accurate.
#   return linalg.solve(XXT + ridge, YXT.T, assume_a="sym")
# /Users/chaitravshetty/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/nodes/readouts/ridge.py:17: LinAlgWarning: Ill-conditioned matrix (rcond=3.30045e-20): result may not be accurate.
#   return linalg.solve(XXT + ridge, YXT.T, assume_a="sym")
# /Users/chaitravshetty/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/nodes/readouts/ridge.py:17: LinAlgWarning: Ill-conditioned matrix (rcond=6.85622e-20): result may not be accurate.
#   return linalg.solve(XXT + ridge, YXT.T, assume_a="sym")
# /Users/chaitravshetty/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/nodes/readouts/ridge.py:17: LinAlgWarning: Ill-conditioned matrix (rcond=1.06094e-16): result may not be accurate.
#   return linalg.solve(XXT + ridge, YXT.T, assume_a="sym")
# /Users/chaitravshetty/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/nodes/readouts/ridge.py:17: LinAlgWarning: Ill-conditioned matrix (rcond=5.48482e-21): result may not be accurate.
#   return linalg.solve(XXT + ridge, YXT.T, assume_a="sym")
# /Users/chaitravshetty/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/nodes/readouts/ridge.py:17: LinAlgWarning: Ill-conditioned matrix (rcond=8.51944e-21): result may not be accurate.
#   return linalg.solve(XXT + ridge, YXT.T, assume_a="sym")
# /Users/chaitravshetty/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/nodes/readouts/ridge.py:17: LinAlgWarning: Ill-conditioned matrix (rcond=5.07271e-17): result may not be accurate.
#   return linalg.solve(XXT + ridge, YXT.T, assume_a="sym")
# /Users/chaitravshetty/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/nodes/readouts/ridge.py:17: LinAlgWarning: Ill-conditioned matrix (rcond=5.49938e-18): result may not be accurate.
#   return linalg.solve(XXT + ridge, YXT.T, assume_a="sym")
# /Users/chaitravshetty/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/nodes/readouts/ridge.py:17: LinAlgWarning: Ill-conditioned matrix (rcond=1.96169e-20): result may not be accurate.
#   return linalg.solve(XXT + ridge, YXT.T, assume_a="sym")
# /Users/chaitravshetty/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/nodes/readouts/ridge.py:17: LinAlgWarning: Ill-conditioned matrix (rcond=4.73831e-20): result may not be accurate.
#   return linalg.solve(XXT + ridge, YXT.T, assume_a="sym")
# /Users/chaitravshetty/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/nodes/readouts/ridge.py:17: LinAlgWarning: Ill-conditioned matrix (rcond=6.99063e-20): result may not be accurate.
#   return linalg.solve(XXT + ridge, YXT.T, assume_a="sym")
# /Users/chaitravshetty/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/nodes/readouts/ridge.py:17: LinAlgWarning: Ill-conditioned matrix (rcond=2.82383e-19): result may not be accurate.
#   return linalg.solve(XXT + ridge, YXT.T, assume_a="sym")
# /Users/chaitravshetty/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/nodes/readouts/ridge.py:17: LinAlgWarning: Ill-conditioned matrix (rcond=1.13551e-18): result may not be accurate.
#   return linalg.solve(XXT + ridge, YXT.T, assume_a="sym")
# /Users/chaitravshetty/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/nodes/readouts/ridge.py:17: LinAlgWarning: Ill-conditioned matrix (rcond=9.01397e-17): result may not be accurate.
#   return linalg.solve(XXT + ridge, YXT.T, assume_a="sym")
# /Users/chaitravshetty/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/nodes/readouts/ridge.py:17: LinAlgWarning: Ill-conditioned matrix (rcond=2.34656e-24): result may not be accurate.
#   return linalg.solve(XXT + ridge, YXT.T, assume_a="sym")
# /Users/chaitravshetty/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/nodes/readouts/ridge.py:17: LinAlgWarning: Ill-conditioned matrix (rcond=2.84496e-19): result may not be accurate.
#   return linalg.solve(XXT + ridge, YXT.T, assume_a="sym")
# /Users/chaitravshetty/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/nodes/readouts/ridge.py:17: LinAlgWarning: Ill-conditioned matrix (rcond=1.32329e-17): result may not be accurate.
#   return linalg.solve(XXT + ridge, YXT.T, assume_a="sym")
# /Users/chaitravshetty/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/nodes/readouts/ridge.py:17: LinAlgWarning: Ill-conditioned matrix (rcond=1.29388e-19): result may not be accurate.
#   return linalg.solve(XXT + ridge, YXT.T, assume_a="sym")
# /Users/chaitravshetty/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/nodes/readouts/ridge.py:17: LinAlgWarning: Ill-conditioned matrix (rcond=1.06032e-18): result may not be accurate.
#   return linalg.solve(XXT + ridge, YXT.T, assume_a="sym")
# /Users/chaitravshetty/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/nodes/readouts/ridge.py:17: LinAlgWarning: Ill-conditioned matrix (rcond=2.8517e-20): result may not be accurate.
#   return linalg.solve(XXT + ridge, YXT.T, assume_a="sym")
# Generation 0: Best RMSE: 1.243909235414727, Best MAE: 0.1749402445208309, Best MSE: 72.44536270728013
# /Users/chaitravshetty/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/nodes/readouts/ridge.py:17: LinAlgWarning: Ill-conditioned matrix (rcond=5.87242e-21): result may not be accurate.
#   return linalg.solve(XXT + ridge, YXT.T, assume_a="sym")
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 18
#      14         print(f"Generation {generation}: Best RMSE: {min(metrics['RMSE'])}, Best MAE: {min(metrics['MAE'])}, Best MSE: {min(metrics['MSE'])}")
#      16     plot_metrics(metrics, "Evolution of Performance Metrics")
# ---> 18 run_evolution(population_size, genome_length, n_generations, X_train, Y_train, X_test, Y_test)
#
# Cell In[20], line 6, in run_evolution(population_size, genome_length, n_generations, X_train, Y_train, X_test, Y_test)
#       3 metrics = {'RMSE': [], 'MAE': [], 'MSE': []}
#       5 for generation in range(n_generations):
# ----> 6     fitness_scores = [evaluate_fitness(genome, X_train, Y_train, X_test, Y_test) for genome in population]
#       7     metrics['RMSE'].append(np.mean([fs[0] for fs in fitness_scores]))
#       8     metrics['MAE'].append(np.mean([fs[1] for fs in fitness_scores]))
#
# Cell In[20], line 6, in <listcomp>(.0)
#       3 metrics = {'RMSE': [], 'MAE': [], 'MSE': []}
#       5 for generation in range(n_generations):
# ----> 6     fitness_scores = [evaluate_fitness(genome, X_train, Y_train, X_test, Y_test) for genome in population]
#       7     metrics['RMSE'].append(np.mean([fs[0] for fs in fitness_scores]))
#       8     metrics['MAE'].append(np.mean([fs[1] for fs in fitness_scores]))
#
# Cell In[14], line 44, in evaluate_fitness(genome, X_train, Y_train, X_test, Y_test)
#      41 model = setup_model(model_config)
#      43 # Train the model and generate predictions
# ---> 44 model.fit(X_train, Y_train)
#      45 predictions = model.run(X_test)
#      47 rmse, mae, mse = evaluate_performance(Y_test, predictions)
#
# File ~/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/model.py:1087, in Model.fit(self, X, Y, warmup, force_teachers, from_state, stateful, reset)
#    1081 if not any([n for n in self.trainable_nodes if n.is_trained_offline]):
#    1082     raise TypeError(
#    1083         f"Impossible to fit model {self} offline: "
#    1084         "no offline nodes found in model."
#    1085     )
# -> 1087 X, Y = to_data_mapping(self, X, Y)
#    1089 self._initialize_on_sequence(X[0], Y[0])
#    1090 self.initialize_buffers()
#
# File ~/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/utils/model_utils.py:162, in to_data_mapping(model, X, Y)
#     159 if Y is not None:
#     160     Y_map = build_mapping(model.trainable_nodes, Y, io_type="target")
# --> 162 X_map, Y_map = check_xy(model, x=X_map, y=Y_map)
#     164 X_sequences = unfold_mapping(X_map)
#     166 if Y_map is None:
#
# File ~/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/_base.py:390, in check_xy(caller, x, y, input_dim, output_dim, allow_n_sequences, allow_n_inputs, allow_timespans)
#     387         if output_dim is None and hasattr(caller, "output_dim"):
#     388             output_dim = caller.output_dim
# --> 390     y_new = _check_node_io(
#     391         y,
#     392         receiver_nodes=trainable_nodes,
#     393         expected_dim=output_dim,
#     394         caller=caller,
#     395         io_type="target",
#     396         allow_n_sequences=allow_n_sequences,
#     397         allow_timespans=allow_timespans,
#     398         allow_n_inputs=False,
#     399     )
#     401 return x_new, y_new
#
# File ~/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/_base.py:253, in _check_node_io(x, receiver_nodes, expected_dim, caller, io_type, allow_n_sequences, allow_n_inputs, allow_timespans)
#     250             else:
#     251                 dim = node.input_dim
# --> 253             x_new[node.name] = check_n_sequences(
#     254                 x_new[node.name],
#     255                 expected_dim=dim,
#     256                 caller=node,
#     257                 allow_n_sequences=allow_n_sequences,
#     258                 allow_n_inputs=allow_n_inputs,
#     259                 allow_timespans=allow_timespans,
#     260             )
#     261 # Caller is a Node
#     262 else:
#     263     if (
#     264         callable(x)
#     265         and hasattr(x, "initialize")
#     266         and hasattr(x, "is_initialized")
#     267         and hasattr(x, "output_dim")
#     268     ):
#
# File ~/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/_base.py:136, in check_n_sequences(x, expected_dim, allow_n_sequences, allow_n_inputs, allow_timespans, caller)
#     134     x_new = [x[i] for i in range(len(x))]
#     135     for i in range(len(x)):
# --> 136         x_new[i] = check_one_sequence(
#     137             x[i],
#     138             allow_timespans=allow_timespans,
#     139             expected_dim=dim,
#     140             caller=caller,
#     141         )
#     142 else:
#     143     if len(x.shape) <= len(dim) + 1:  # only one sequence
#
# File ~/Downloads/Advanced-Genomes-for-Evolutionary-Computing-main 3/hierarchical_genomes/.venv/lib/python3.10/site-packages/reservoirpy/_base.py:70, in check_one_sequence(x, expected_dim, caller, allow_timespans)
#      68     for dim in expected_dim:
#      69         if all([dim != ddim for ddim in data_dim]):
# ---> 70             raise ValueError(
#      71                 f"{caller_name} expecting data of shape "
#      72                 f"{expected_dim} but received shape {data_dim}."
#      73             )
#      74 return x_new
#
# ValueError: Ridge-152is  expecting data of shape (-6,) but received shape (1,).
